# %%
import requests

url = "https://api.perplexity.ai/v1/embeddings"
headers = {
    "Authorization": "Bearer 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",  # Replace with your real API key
    "Content-Type": "application/json"
}
data = {
    "model": "sonar-embedding-001",  # Valid embedding model name per official docs
    "input": "Your text to embed"
}

response = requests.post(url, json=data, headers=headers)

# Print raw response for debugging if needed
print("Raw response:", response.text)

try:
    json_response = response.json()
    embedding_vector = json_response["data"][0]["embedding"]
    print("Embedding vector:", embedding_vector)
except Exception as e:
    print("Failed to parse JSON response:", e)
# Out:
# Raw response:
# Failed to parse JSON response: Expecting value: line 1 column 1 (char 0)

# %%
import psycopg2
from utils.config import POSTGRES_CONFIG

conn = psycopg2.connect(**POSTGRES_CONFIG)
print("✅ Connected successfully!")
conn.close()
# Out:
# ✅ Connected successfully!

# %%
print("Postgres Config:", POSTGRES_CONFIG)
# Out:
# Postgres Config: {'dbname': 'JARVIS', 'user': 'karthimurugesan', 'password': '', 'host': 'localhost', 'port': 5432}
